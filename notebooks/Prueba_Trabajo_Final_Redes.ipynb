# %% [markdown]
# # Trabajo Final Ciencia de Redes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
#from Funciones.GEO_LIB import Plot, Poligono, Distancia, Geodecodificacion
from tqdm import tqdm
from scipy import stats
import numpy as np
import community as community_louvain
import networkx as nx
from itertools import count
import matplotlib.pyplot as plt 
import matplotlib.cm as cm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 from scipy import stats
#       7 import numpy as np
# ----> 8 import community as community_louvain
#       9 import networkx as nx
#      10 from itertools import count
#
# ModuleNotFoundError: No module named 'community'

# %%
data = pd.read_excel("../data/consolidado_reviews_Los_Ríos.xlsx")

# %%
data.head()
# Out:
#     N                     place_id                   name  \
# 0  89  ChIJS5lcdLBVEZYRFa_Y_RuCV1g  Restaurant Puerto Fuy
# 1  89  ChIJS5lcdLBVEZYRFa_Y_RuCV1g  Restaurant Puerto Fuy
# 2  89  ChIJS5lcdLBVEZYRFa_Y_RuCV1g  Restaurant Puerto Fuy
# 3  89  ChIJS5lcdLBVEZYRFa_Y_RuCV1g  Restaurant Puerto Fuy
# 4  89  ChIJS5lcdLBVEZYRFa_Y_RuCV1g  Restaurant Puerto Fuy
#
#                               id_review                         user_name  \
# 0  ChdDSUhNMG9nS0VJQ0FnSURYbzgzN29BRRAB                     angie cardona
# 1  ChdDSUhNMG9nS0VJQ0FnSURYMmJPampnRRAB                     Fabian Aruani
# 2   ChZDSUhNMG9nS0VJQ0FnSURYb01lUkFREAE                   Nataniel Lavado
# 3  ChdDSUhNMG9nS0VJQ0FnSUNYLTdiY2tBRRAB  Leonardo Enrique García Riquelme
# 4  ChdDSUhNMG9nS0VJQ0FnSUNYdTdlYTZBRRAB                    Andres Herrera
#
#               id_usuario  stars  \
# 0  103326493536057771398      5
# 1  117348510194376829755      3
# 2  115312318540115775891      5
# 3  100519139671583772741      4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479343 entries, 0 to 479342
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   N            479343 non-null  int64
#  1   place_id     479343 non-null  object
#  2   name         479343 non-null  object
#  3   id_review    479343 non-null  object
#  4   user_name    479343 non-null  object
#  5   id_usuario   479343 non-null  object
#  6   stars        479343 non-null  int64
#  7   link_review  479343 non-null  object
#  8   fecha        479343 non-null  object
#  9   review       233588 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 36.6+ MB

# %%
# Seleccionar 1000 filas aleatorias
sampled_data = data.sample(n=1000, random_state=42)

# Mostrar el resultado
print(sampled_data)
# Out:
#           N                     place_id  \
# 295607  327  ChIJH0BxTUXvFZYRfbgwBMfXGlA
# 401697    2  ChIJlTOXxML2FZYRmZFsQRQw0hc
# 349965   66  ChIJo_kcKOb7E5YRvA0SROCn7vE
# 21587   100  ChIJzZ1YKHfuFZYRmrUoiXVOe_0
# 51241    13  ChIJgZFwLt_tFZYRS6o-h0legKc
# ...     ...                          ...
# 148859  203  ChIJ6yJcdpedFZYR9XGbv7W4KCM
# 287772   61  ChIJyexd0yO-FZYR_pLsI51Q1eE
# 453007    7  ChIJUdgVg6qqFpYR85FArcIFSf8
# 346162  595  ChIJAV98xBRGFJYRVhOVd9pB2zA
# 266237  250  ChIJVyGmqC8-FJYR-ph5ShPJj9s
#
#                                                      name  \
# 295607                               Fusión 640 gastrobar
# 401697  Encuentro Costumbrista en la Costa Playa Grand...
# 349965                                  Termas Manquecura
# 21587                                    Clover Irish Pub
# 51241                               Costanera Arturo Prat
# ...                                                   ...
# ...

# %%
sampled_data.to_csv("../data/sampled_data.csv", index=False, encoding="utf-8")
